# %% [markdown]
# World Bank Projects & Operations provides access to basic information on all of the World Bank's lending projects from 1947 to the present. The dataset includes basic information such as the project title, task manager, country, project id, sector, themes, commitment amount, product line, and financing. It also provides links to publicly disclosed online documents.

# %% [markdown]
# Using the status variable build a binary classifier to predict the probability
# whether a project will be “closed” or “canceled/distressed

# %%
#convert xls to csv 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
read_file = pd.read_excel ("world_bank_data.xls")
  
# Write the dataframe object
# into csv file
read_file.to_csv ("bank_data.csv", 
                  index = None,
                  header=True)
    
# read csv file and convert 
# into a dataframe object
df = pd.DataFrame(pd.read_csv("bank_data.csv"))
  
# show the dataframe
df
# Out:
#       World Bank Projects, data as of 06/13/2022 22:00:02 EST  \
# 0                                             Project ID
# 1                                                     id
# 2                                                P252350
# 3                                                P252338
# 4                                                P252337
# ...                                                  ...
# 21540                                            P000019
# 21541                                            P000017
# 21542                                            P000010
# 21543                                            P000003
# 21544                                            P000001
#
#                         Unnamed: 1                          Unnamed: 2  \
# 0                           Region                             Country
# 1                       regionname                         countryname
# 2      Eastern and Southern Africa                  Republic of Rwanda
# 3            East Asia and Pacific  Democratic Republic of Timor-Leste
# 4      Eastern and Southern Africa                   Republic of Kenya
# ...                            ...                                 ...
# 21540                       Africa                              Africa
# 21541                       Africa                              Africa
# 21542                       Africa                              Africa
# 21543                       Africa                              Africa
# 21544                       Africa                              Africa
#
#                  Unnamed: 3               Unnamed: 4  \
# 0            Project Status  Last Stage Reached Name
# 1      projectstatusdisplay  last_stage_reached_name
# 2                    Active            Bank Approved
# 3                    Active            Bank Approved
# 4                   Dropped           Concept Review
# ...                     ...                      ...
# 21540               Dropped                      NaN
# 21541                Closed            Bank Approved
# 21542                Closed                      NaN
# 21543                Closed            Bank Approved
# 21544                Closed            Bank Approved
#
#                                               Unnamed: 5  \
# 0                                           Project Name
# 1                                           project_name
# 2                Rwanda Priority Skills for Growth (PSG)
# 3      Road Climate Resilience Project Second Additio...
# 4                  Kenya Devolution and Service Delivery
# ...                                                  ...
# 21540            UEMOA Regional Financial Sector Project
# 21541       Engineering and Technical Assistance Project
# 21542                  Regional Development Project (03)
# 21543                                REIMP(CEN.ENV.INFO)
# 21544  West Africa Pilot Community-based Natural Reso...
#
#                                               Unnamed: 6  \
# 0                         Project Development Objective
# 1                                                    pdo
# 2      The Program Development Objective is to expand...
# 3      The project will deliver sustainable climate r...
# 4      To improve citizen and government access to co...
# ...                                                  ...
# 21540                                                NaN
# 21541                                                NaN
# 21542                                                NaN
# 21543                                                NaN
# 21544                                                NaN
#
#                                               Unnamed: 7  \
# 0                                    Implementing Agency
# 1                                              impagency
# 2                                  Ministry Of Education
# 3      Ministry of Public Works, Transport, and Commu...
# 4                    Kenya National Bureau of Statistics
# ...                                                  ...
# 21540                                                NaN
# 21541                                                NaN
# 21542                                                NaN
# 21543                                                NaN
# 21544                                                NaN
#
#                          Unnamed: 8  \
# 0      Consultant Services Required
# 1                cons_serv_reqd_ind
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 21540                           NaN
# 21541                           NaN
# 21542                           NaN
# 21543                           NaN
# 21544                           NaN
#
#                                               Unnamed: 9  ...   Unnamed: 17  \
# 0                                            Project URL  ...  Grant Amount
# 1                                                    url  ...      grantamt
# 2      http://projects.worldbank.org/P252350/null?lan...  ...             0
# 3      http://projects.worldbank.org/P252338/null?lan...  ...             0
# 4      http://projects.worldbank.org/P252337/null?lan...  ...        340000
# ...                                                  ...  ...           ...
# 21540  http://projects.worldbank.org/P000019/null?lan...  ...             0
# 21541  http://projects.worldbank.org/P000017/engineer...  ...             0
# 21542  http://projects.worldbank.org/P000010/null?lan...  ...             0
# 21543  http://projects.worldbank.org/P000003/reimpcen...  ...       4100000
# 21544  http://projects.worldbank.org/P000001/west-afr...  ...       4400000
#
#                                      Unnamed: 18  \
# 0                                       Borrower
# 1                                       borrower
# 2      Ministry of Finance and Economic Planning
# 3                            Ministry of Finance
# 4            Kenya National Bureau of Statistics
# ...                                          ...
# 21540                                        NaN
# 21541                                        NaN
# 21542                                        NaN
# 21543                                        NaN
# 21544                                        NaN
#
#                          Unnamed: 19                        Unnamed: 20  \
# 0                 Lending Instrument  Environmental Assessment Category
# 1                       lendinginstr           envassesmentcategorycode
# 2      Program-for-Results Financing                                NaN
# 3       Investment Project Financing                                  B
# 4       Investment Project Financing                                  C
# ...                              ...                                ...
# 21540       Specific Investment Loan                                  C
# 21541      Technical Assistance Loan                                  C
# 21542    Financial Intermediary Loan                                  B
# 21543       Specific Investment Loan                                  C
# 21544       Specific Investment Loan                                  B
#
#                          Unnamed: 21                             Unnamed: 22  \
# 0      Environmental and Social Risk                                Sector 1
# 1                esrc_ovrl_risk_rate                                 sector1
# 2                                NaN       Public Administration - Education
# 3                                NaN  Public Administration - Transportation
# 4                                NaN                                     NaN
# ...                              ...                                     ...
# 21540                            NaN                                     NaN
# 21541                            NaN                                   Power
# 21542                            NaN                    Banking Institutions
# 21543                            NaN             Other Public Administration
# 21544                            NaN                 Sub-National Government
#
#                                              Unnamed: 23  \
# 0                                               Sector 2
# 1                                                sector2
# 2                                     Tertiary Education
# 3                            Rural and Inter-Urban Roads
# 4                                                    NaN
# ...                                                  ...
# 21540                                                NaN
# 21541                                                NaN
# 21542            Other Agriculture, Fishing and Forestry
# 21543  Other Information and Communications Technologies
# 21544                                  Social Protection
#
#                                           Unnamed: 24  \
# 0                                            Sector 3
# 1                                             sector3
# 2      Workforce Development and Vocational Education
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 21540                                             NaN
# 21541                                             NaN
# 21542                            Other Transportation
# 21543                               Social Protection
# 21544         Other Agriculture, Fishing and Forestry
#
#                                              Unnamed: 25  \
# 0                                                Theme 1
# 1                                                 theme1
# 2                    Education for the knowledge economy
# 3                                                    NaN
# 4      Public expenditure, financial management and p...
# ...                                                  ...
# 21540                                                NaN
# 21541            Legal institutions for a market economy
# 21542            Environmental policies and institutions
# 21543                 Land administration and management
# 21544                  Rural services and infrastructure
#
#                                           Unnamed: 26
# 0                                             Theme 2
# 1                                              theme2
# 2                                                 NaN
# 3                                                 NaN
# 4                                    Decentralization
# ...                                               ...
# 21540                                             NaN
# 21541                            Regional integration
# 21542  Other financial and private sector development
# 21543         Environmental policies and institutions
# 21544                                    Biodiversity
#
# [21545 rows x 27 columns]

# %% [markdown]
# Finding Null values and dropping unecessary columns

# %%
#take 1st row in a list 
df.iloc[0] = df.iloc[0].tolist()
df.columns = df.iloc[0]

# %%
df
# Out:
# 0      Project ID                       Region  \
# 0      Project ID                       Region
# 1              id                   regionname
# 2         P252350  Eastern and Southern Africa
# 3         P252338        East Asia and Pacific
# 4         P252337  Eastern and Southern Africa
# ...           ...                          ...
# 21540     P000019                       Africa
# 21541     P000017                       Africa
# 21542     P000010                       Africa
# 21543     P000003                       Africa
# 21544     P000001                       Africa
#
# 0                                 Country        Project Status  \
# 0                                 Country        Project Status
# 1                             countryname  projectstatusdisplay
# 2                      Republic of Rwanda                Active
# 3      Democratic Republic of Timor-Leste                Active
# 4                       Republic of Kenya               Dropped
# ...                                   ...                   ...
# 21540                              Africa               Dropped
# 21541                              Africa                Closed
# 21542                              Africa                Closed
# 21543                              Africa                Closed
# 21544                              Africa                Closed
#
# 0      Last Stage Reached Name  \
# 0      Last Stage Reached Name
# 1      last_stage_reached_name
# 2                Bank Approved
# 3                Bank Approved
# 4               Concept Review
# ...                        ...
# 21540                      NaN
# 21541            Bank Approved
# 21542                      NaN
# 21543            Bank Approved
# 21544            Bank Approved
#
# 0                                           Project Name  \
# 0                                           Project Name
# 1                                           project_name
# 2                Rwanda Priority Skills for Growth (PSG)
# 3      Road Climate Resilience Project Second Additio...
# 4                  Kenya Devolution and Service Delivery
# ...                                                  ...
# 21540            UEMOA Regional Financial Sector Project
# 21541       Engineering and Technical Assistance Project
# 21542                  Regional Development Project (03)
# 21543                                REIMP(CEN.ENV.INFO)
# 21544  West Africa Pilot Community-based Natural Reso...
#
# 0                         Project Development Objective   \
# 0                         Project Development Objective
# 1                                                    pdo
# 2      The Program Development Objective is to expand...
# 3      The project will deliver sustainable climate r...
# 4      To improve citizen and government access to co...
# ...                                                  ...
# 21540                                                NaN
# 21541                                                NaN
# 21542                                                NaN
# 21543                                                NaN
# 21544                                                NaN
#
# 0                                    Implementing Agency  \
# 0                                    Implementing Agency
# 1                                              impagency
# 2                                  Ministry Of Education
# 3      Ministry of Public Works, Transport, and Commu...
# 4                    Kenya National Bureau of Statistics
# ...                                                  ...
# 21540                                                NaN
# 21541                                                NaN
# 21542                                                NaN
# 21543                                                NaN
# 21544                                                NaN
#
# 0      Consultant Services Required  \
# 0      Consultant Services Required
# 1                cons_serv_reqd_ind
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 21540                           NaN
# 21541                           NaN
# 21542                           NaN
# 21543                           NaN
# 21544                           NaN
#
# 0                                            Project URL  ...  Grant Amount  \
# 0                                            Project URL  ...  Grant Amount
# 1                                                    url  ...      grantamt
# 2      http://projects.worldbank.org/P252350/null?lan...  ...             0
# 3      http://projects.worldbank.org/P252338/null?lan...  ...             0
# 4      http://projects.worldbank.org/P252337/null?lan...  ...        340000
# ...                                                  ...  ...           ...
# 21540  http://projects.worldbank.org/P000019/null?lan...  ...             0
# 21541  http://projects.worldbank.org/P000017/engineer...  ...             0
# 21542  http://projects.worldbank.org/P000010/null?lan...  ...             0
# 21543  http://projects.worldbank.org/P000003/reimpcen...  ...       4100000
# 21544  http://projects.worldbank.org/P000001/west-afr...  ...       4400000
#
# 0                                       Borrower  \
# 0                                       Borrower
# 1                                       borrower
# 2      Ministry of Finance and Economic Planning
# 3                            Ministry of Finance
# 4            Kenya National Bureau of Statistics
# ...                                          ...
# 21540                                        NaN
# 21541                                        NaN
# 21542                                        NaN
# 21543                                        NaN
# 21544                                        NaN
#
# 0                 Lending Instrument  Environmental Assessment Category  \
# 0                 Lending Instrument  Environmental Assessment Category
# 1                       lendinginstr           envassesmentcategorycode
# 2      Program-for-Results Financing                                NaN
# 3       Investment Project Financing                                  B
# 4       Investment Project Financing                                  C
# ...                              ...                                ...
# 21540       Specific Investment Loan                                  C
# 21541      Technical Assistance Loan                                  C
# 21542    Financial Intermediary Loan                                  B
# 21543       Specific Investment Loan                                  C
# 21544       Specific Investment Loan                                  B
#
# 0      Environmental and Social Risk                                Sector 1  \
# 0      Environmental and Social Risk                                Sector 1
# 1                esrc_ovrl_risk_rate                                 sector1
# 2                                NaN       Public Administration - Education
# 3                                NaN  Public Administration - Transportation
# 4                                NaN                                     NaN
# ...                              ...                                     ...
# 21540                            NaN                                     NaN
# 21541                            NaN                                   Power
# 21542                            NaN                    Banking Institutions
# 21543                            NaN             Other Public Administration
# 21544                            NaN                 Sub-National Government
#
# 0                                               Sector 2  \
# 0                                               Sector 2
# 1                                                sector2
# 2                                     Tertiary Education
# 3                            Rural and Inter-Urban Roads
# 4                                                    NaN
# ...                                                  ...
# 21540                                                NaN
# 21541                                                NaN
# 21542            Other Agriculture, Fishing and Forestry
# 21543  Other Information and Communications Technologies
# 21544                                  Social Protection
#
# 0                                            Sector 3  \
# 0                                            Sector 3
# 1                                             sector3
# 2      Workforce Development and Vocational Education
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 21540                                             NaN
# 21541                                             NaN
# 21542                            Other Transportation
# 21543                               Social Protection
# 21544         Other Agriculture, Fishing and Forestry
#
# 0                                                Theme 1  \
# 0                                                Theme 1
# 1                                                 theme1
# 2                    Education for the knowledge economy
# 3                                                    NaN
# 4      Public expenditure, financial management and p...
# ...                                                  ...
# 21540                                                NaN
# 21541            Legal institutions for a market economy
# 21542            Environmental policies and institutions
# 21543                 Land administration and management
# 21544                  Rural services and infrastructure
#
# 0                                             Theme 2
# 0                                             Theme 2
# 1                                              theme2
# 2                                                 NaN
# 3                                                 NaN
# 4                                    Decentralization
# ...                                               ...
# 21540                                             NaN
# 21541                            Regional integration
# 21542  Other financial and private sector development
# 21543         Environmental policies and institutions
# 21544                                    Biodiversity
#
# [21545 rows x 27 columns]

# %%
#drop columns 
# 'Consultant Services Required', 'Project Development Objective', 'Implementing Agency' , 'Project URL', 'Borrower', 'Environmental Assessment Category', 'Environmental and Social Risk'
df.drop(['Consultant Services Required', 'Implementing Agency' , 'Project URL', 'Borrower', 'Environmental Assessment Category', 'Environmental and Social Risk'], axis=1, inplace=True)

# %%
df.head()
# Out:
# 0  Project ID                       Region  \
# 0  Project ID                       Region
# 1          id                   regionname
# 2     P252350  Eastern and Southern Africa
# 3     P252338        East Asia and Pacific
# 4     P252337  Eastern and Southern Africa
#
# 0                             Country        Project Status  \
# 0                             Country        Project Status
# 1                         countryname  projectstatusdisplay
# 2                  Republic of Rwanda                Active
# 3  Democratic Republic of Timor-Leste                Active
# 4                   Republic of Kenya               Dropped
#
# 0  Last Stage Reached Name                                       Project Name  \
# 0  Last Stage Reached Name                                       Project Name
# 1  last_stage_reached_name                                       project_name
# 2            Bank Approved            Rwanda Priority Skills for Growth (PSG)
# 3            Bank Approved  Road Climate Resilience Project Second Additio...
# 4           Concept Review              Kenya Devolution and Service Delivery
#
# 0                     Project Development Objective    Board Approval Date  \
# 0                     Project Development Objective    Board Approval Date
# 1                                                pdo     boardapprovaldate
# 2  The Program Development Objective is to expand...  2017-07-05T00:00:00Z
# 3  The project will deliver sustainable climate r...  2017-04-27T00:00:00Z
# 4  To improve citizen and government access to co...                   NaN
#
# 0   Project Closing Date        Financing Type  ...      IBRD Commitment   \
# 0   Project Closing Date        Financing Type  ...      IBRD Commitment
# 1            closingdate  projectfinancialtype  ...  curr_ibrd_commitment
# 2  9/30/2023 12:00:00 AM                   IDA  ...                     0
# 3                    NaN                   NaN  ...                     0
# 4                    NaN                   NaN  ...                     0
#
# 0       IDA Commitment  Total IDA and IBRD Commitment  Grant Amount  \
# 0       IDA Commitment  Total IDA and IBRD Commitment  Grant Amount
# 1  curr_ida_commitment          curr_total_commitment      grantamt
# 2            120000000                      120000000             0
# 3             35200000                       35200000             0
# 4                    0                              0        340000
#
# 0             Lending Instrument                                Sector 1  \
# 0             Lending Instrument                                Sector 1
# 1                   lendinginstr                                 sector1
# 2  Program-for-Results Financing       Public Administration - Education
# 3   Investment Project Financing  Public Administration - Transportation
# 4   Investment Project Financing                                     NaN
#
# 0                     Sector 2  \
# 0                     Sector 2
# 1                      sector2
# 2           Tertiary Education
# 3  Rural and Inter-Urban Roads
# 4                          NaN
#
# 0                                        Sector 3  \
# 0                                        Sector 3
# 1                                         sector3
# 2  Workforce Development and Vocational Education
# 3                                             NaN
# 4                                             NaN
#
# 0                                            Theme 1           Theme 2
# 0                                            Theme 1           Theme 2
# 1                                             theme1            theme2
# 2                Education for the knowledge economy               NaN
# 3                                                NaN               NaN
# 4  Public expenditure, financial management and p...  Decentralization
#
# [5 rows x 21 columns]

# %%
#convert project status to numeric 
df['Project Status'] = df['Project Status'].replace(['Completed', 'Cancelled', 'In Progress', 'Not Started'], [1, 2, 3, 4])
